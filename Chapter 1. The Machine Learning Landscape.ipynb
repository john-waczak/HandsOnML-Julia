# %% [markdown]
# # What is Machine Learning
#
# **Definition:** *Machine Learning* is the field of study that gives computers the ability to learn without being explicitly programmed

# %% [markdown]
# Set up the environment

# %%
using Pkg
Pkg.add("MLJ")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#    Installed EarlyStopping ──── v0.1.9
#    Installed InverseFunctions ─ v0.1.1
#    Installed LogExpFunctions ── v0.3.4
#    Installed SpecialFunctions ─ v1.8.0
#    Installed ChainRulesCore ─── v1.10.1
#    Installed TimeZones ──────── v1.6.1
#    Installed MLJIteration ───── v0.3.3
#    Installed PrettyTables ───── v1.2.3
#    Installed MLJ ────────────── v0.16.10
#    Installed Distances ──────── v0.10.5
#     Updating `~/gitRepos/HandsOnML-Julia/Project.toml`
#   [add582a8] + MLJ v0.16.10
#     Updating `~/gitRepos/HandsOnML-Julia/Manifest.toml`
#   [da404889] + ARFFFiles v1.4.0
#   [fbb218c0] + BSON v0.3.4
#   [324d7699] + CategoricalArrays v0.10.1
#   [d360d2e6] + ChainRulesCore v1.10.1
#   [944b1d66] + CodecZlib v0.7.0
#   [3da002f7] + ColorTypes v0.11.0
#   [34da2185] + Compat v3.39.0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [a8cc5b0e] + Crayons v4.0.4
# ...

# %%
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#    Installed Latexify ─ v0.15.8
#     Updating `~/gitRepos/HandsOnML-Julia/Project.toml`
#   [91a5bcdd] + Plots v1.22.6
#     Updating `~/gitRepos/HandsOnML-Julia/Manifest.toml`
#   [79e6a3ab] + Adapt v3.3.1
#   [35d6a980] + ColorSchemes v3.15.0
#   [5ae59095] + Colors v0.12.8
#   [d38c429a] + Contour v0.5.7
#   [c87230d0] + FFMPEG v0.4.1
#   [28b8d3ca] + GR v0.61.0
#   [5c1252a2] + GeometryBasics v0.4.1
#   [42e2da0e] + Grisu v1.0.2
#   [c8e1da08] + IterTools v1.3.0
#   [b964fa9f] + LaTeXStrings v1.2.1
#   [23fbe1c1] + Latexify v0.15.8
#   [1914dd2f] + MacroTools v0.5.8
#   [442fdcdd] + Measures v0.3.1
#   [77ba4419] + NaNMath v0.3.5
#   [ccf2f8ad] + PlotThemes v2.0.1
#   [995b91a9] + PlotUtils v1.0.15
#   [91a5bcdd] + Plots v1.22.6
#   [01d81517] + RecipesPipeline v0.4.1
#   [6c6a2e73] + Scratch v1.1.0
#   [992d4aef] + Showoff v1.0.3
#   [90137ffa] + StaticArrays v1.2.13
#   [09ab397b] + StructArrays v0.6.3
#   [6e34b625] + Bzip2_jll v1.0.8+0
# ...

# %%
Pkg.add("DataFrames")
Pkg.add("CSV")
# Out:
#    Resolving package versions...
#   No Changes to `~/gitRepos/HandsOnML-Julia/Project.toml`
#   No Changes to `~/gitRepos/HandsOnML-Julia/Manifest.toml`
#    Resolving package versions...
#    Installed CSV ─ v0.9.8
#     Updating `~/gitRepos/HandsOnML-Julia/Project.toml`
#   [336ed68f] + CSV v0.9.8
#     Updating `~/gitRepos/HandsOnML-Julia/Manifest.toml`
#   [336ed68f] + CSV v0.9.8
#   [91c51154] + SentinelArrays v1.3.7
#   [ea10d353] + WeakRefStrings v1.4.1
# Precompiling project...
#   ✓ CSV
#   1 dependency successfully precompiled in 9 seconds (181 already precompiled)

# %%
using Plots 
using DataFrames, CSV
using MLJ
# Out:
# WARNING: both Downloads and Base export "download"; uses of it in module Main must be qualified

# %%
oecd_bli = DataFrame(CSV.File(Base.download("https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/lifesat/oecd_bli_2015.csv")))
# Out:
# 3292×17 DataFrame
#   Row │ LOCATION  Country          INDICATOR  Indicator                        ⋯
#       │ String7   String15         String15   String63                         ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ AUS       Australia        HO_BASE    Dwellings without basic faciliti ⋯
#     2 │ AUT       Austria          HO_BASE    Dwellings without basic faciliti
#     3 │ BEL       Belgium          HO_BASE    Dwellings without basic faciliti
#     4 │ CAN       Canada           HO_BASE    Dwellings without basic faciliti
#     5 │ CZE       Czech Republic   HO_BASE    Dwellings without basic faciliti ⋯
#     6 │ DNK       Denmark          HO_BASE    Dwellings without basic faciliti
#     7 │ FIN       Finland          HO_BASE    Dwellings without basic faciliti
#     8 │ FRA       France           HO_BASE    Dwellings without basic faciliti
# ...

# %%
gdp_per_capita = DataFrame(CSV.File(Base.download("https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/lifesat/gdp_per_capita.csv")))
# Out:
# ┌ Warning: thread = 1 warning: only found 1 / 7 columns around data row: 190. Filling remaining columns with `missing`
# └ @ CSV /home/john/.julia/packages/CSV/AMDwS/src/file.jl:634
# ┌ Warning: thread = 1 warning: only found 1 / 7 columns around data row: 190. Filling remaining columns with `missing`
# └ @ CSV /home/john/.julia/packages/CSV/AMDwS/src/file.jl:634
# 190×7 DataFrame
#  Row │ Country                            Subject Descriptor                 U ⋯
#      │ String                             String?                            S ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Afghanistan                        Gross domestic product per capit…  U ⋯
#    2 │ Albania                            Gross domestic product per capit…  U
#    3 │ Algeria                            Gross domestic product per capit…  U
#    4 │ Angola                             Gross domestic product per capit…  U
# ...
